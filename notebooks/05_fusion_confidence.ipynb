# %% [markdown]
# # 05 — EMG + IMU fusion confidence
#
# Phase B (docs/roadmap.md). Whether fusing EMG and IMU improves *confidence*
# rather than raw accuracy (see docs/experiments.md, group C) — feeds
# `reborn.decision.confidence_gate` design choices.
