# %% [markdown]
# # 04 — IMU baselines
#
# Phase B (docs/roadmap.md). Kinematic baseline independent of EMG: angle/
# velocity estimation, drift characterization, and artefact handling (see
# docs/experiments.md, group B).
